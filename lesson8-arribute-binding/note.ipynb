# %% [markdown]
# # 什么是响应性reactivity？
#
# 其实就是这个函数
#
# ```js
# import {ref} from 'vue'
# const name = ref('doctor')
# ```
#
# 可以通过const赋予变量各种类型的值，比如文本、数字、字典、布尔值等

# %% [markdown]
# 注意，你可以通过
#
# some_ref.value= "xxxx"
#
# 直接修改这个ref的值，案例见Header.vue
