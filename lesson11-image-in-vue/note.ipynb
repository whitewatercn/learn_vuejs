# %% [markdown]
# # 如何往vuejs里放图片
#
# 1. 基于绝对路径或，public文件夹里的静态资源，一般放在
# 2. 通过相对路径@，引用src/assets里的资源
# 3. 先导入，然后以组件的形式调用

# %% [markdown]
# | 方法 | 适用场景 | 优点 | 缺点 |
# | :--- | :--- | :--- | :--- |
# | **绝对路径指向 `/public` 文件夹** | 不需要优化的大型或静态资源（如 PDF） | - 简单直接<br>- 文件原样提供<br>- 外部 CSS 易于访问 | - 无 Vite 优化<br>- 难以组织<br>- 可能因浏览器缓存导致不更新 |
# | **指向 `/assets` 文件夹的相对路径 `@`** | 简单项目中的小型静态资源（如所有页面页眉通用的静态 Logo） | - 超级简单<br>- 无需特殊导入 | - 无 Vite 优化<br>- 不支持动态图片<br>- 不模块化 |
# | **导入组件并绑定到 `src` 属性** | 动态图片（如产品照片） | - 经 Vite 优化<br>- 支持条件加载<br>- 模块化且可扩展 | - 写法较繁琐<br>- 初学者可能感到困惑 |
